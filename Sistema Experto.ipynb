# %%
from pyknow import *

# %%
class Movie(Fact):
    """Info about the traffic light."""
    pass

class MovieSelector(KnowledgeEngine):
    valid_answers_genre = dict()
    valid_answers_duration = dict()
    valid_answers_year = dict()
    valid_answers_country = dict()
    movies = dict()
    genre = 'None'
    duration = 'None'
    year = 'None'
    country = 'None'
#-----------------------------INICIALIZACION----------------------------#
    @Rule()
    def startup(self):
        print("Welcome!" )
        print('I will select a movie based on your preferences!')
        print('---------------------------------------------------')
        print('Please, answer the questions:')
        self.get_answers()
        self.inputGenre()
        self.inputDuration()
        self.inputYear()
        self.inputCountry()
        self.get_movie()
        
    def get_answers(self):        
        self.valid_answers_genre['co'] = 'comedy'
        self.valid_answers_genre['cr'] = 'crime'
        self.valid_answers_genre['h'] = 'horror'
        self.valid_answers_genre['sf'] = 'science fiction'
       
        self.valid_answers_duration['long'] = 'long length (+150 mins)'
        self.valid_answers_duration['medium'] = 'medium length (100 - 150 mins)'
        self.valid_answers_duration['short'] = 'short length (-100 mins)'
        
        self.valid_answers_year['1'] = '2022 - 2008'
        self.valid_answers_year['2'] = '2008 - 1998'
        self.valid_answers_year['3'] = '1998 - 1990'
        self.valid_answers_year['4'] = '1989 - 1970'
        
        self.valid_answers_country['international'] = 'international'
        self.valid_answers_country['argentina'] = 'argentina'
        
        self.movies['comedy short 2022 - 2008 international'] = 'Perfect Strangers (2017) Alex de la Iglesia |Netflix'
        self.movies['comedy short 2008 - 1998 international'] = 'The Simpsons Movie (2007) David Silverman |STAR+ / Disney+'
        self.movies['comedy short 1998 - 1990 international'] = 'When Harry Met Sally (1989) Rob Reiner |Amazon Prime Video'
        self.movies['comedy short 1989 - 1970 international'] = 'Annie Hall (1977) Woody Allen |Stremio'
        self.movies['comedy short 2022 - 2008 argentina'] = 'El futbol o yo (2017) Marcos Carnevale |STAR+'
        self.movies['comedy short 2008 - 1998 argentina'] = 'Bañeros III todopoderosos (2006) Rodolfo Ledo |Stremio'
        self.movies['comedy short 1998 - 1990 argentina'] = '100 veces no debo (1990) Alejandro Doria |Stremio'
        self.movies['comedy short 1989 - 1970 argentina'] = 'Esperando la carroza (1985) Alejandro Doria |Netflix'
        self.movies['comedy medium 2022 - 2008 international'] = 'Parasite (2019) Bong Joon-Ho |Netflix'
        self.movies['comedy medium 2008 - 1998 international'] = 'Anything Else (2003) Woody Allen |Stremio'
        self.movies['comedy medium 1998 - 1990 international'] = 'The Truman Show (1998) Peter Wair |Stremio'
        self.movies['comedy medium 1989 - 1970 international'] = 'Hannah and her sisters (1986) Woody Allen |Stremio'
        self.movies['comedy medium 2022 - 2008 argentina'] = 'Relatos Salvajes (2014) Damian Szifron |Stremio'
        self.movies['comedy medium 2008 - 1998 argentina'] = 'Papa es un idolo (2000) Juan Jose Jusid |Stremio'
        self.movies['comedy medium 1998 - 1990 argentina'] = 'Enfermero de día, camarero de noche (1990) Anibal di Salvo |Stremio'
        self.movies['comedy medium 1989 - 1970 argentina'] = 'El profesor patagónico (1970) Fernando Ayala |Stremio'   
        self.movies['comedy long 2022 - 2008 international'] = 'The Wolf of Wall Street (2013) Martin Scorsese |HBO MAX / Stremio'
        self.movies['comedy long 2008 - 1998 international'] = 'Love Actually (2003) Richard Curtis |Amazon Prime Video'
        self.movies['comedy long 1998 - 1990 international'] = 'Forrest Gump (1994) Robert Zemeckis |HBO MAX / Stremio'
        self.movies['comedy long 1989 - 1970 international'] = 'The World According to Garp (1982) George Roy Hill |Stremio'
        self.movies['comedy long 2022 - 2008 argentina'] = 'Igualita a mi (2010) Diego Kaplan |Stremio'
        self.movies['comedy long 2008 - 1998 argentina'] = 'Nueve reinas (2000) Fabián Bielinsky |Netflix'
        self.movies['comedy long 1998 - 1990 argentina'] = 'Enfermero de día, camarero de noche (1990) Anibal di Salvo |Stremio'
        self.movies['comedy long 1989 - 1970 argentina'] = 'El profesor patagónico (1970) Fernando Ayala |Stremio'
        self.movies['crime short 2022 - 2008 international'] = 'Drive (2011) Nicholas Winding Refn |Netflix'
        self.movies['crime short 2008 - 1998 international'] = 'American Psycho (2000) Mary Harron |Stremio'
        self.movies['crime short 1998 - 1990 international'] = 'Reservoir Dogs (1992) Quentin Tarantino |Stremio'
        self.movies['crime short 1989 - 1970 international'] = 'Blood Simple (1984) Joel Coen |Stremio'
        self.movies['crime short 2022 - 2008 argentina'] = 'Muerte en Buenos Aires (2014) Natalia Meta |STAR+'
        self.movies['crime short 2008 - 1998 argentina'] = 'Tiempo de valientes (2005) Damian Szifron |Stremio'
        self.movies['crime short 1998 - 1990 argentina'] = 'El caso de Maria Soledad (1993) Hector Olivera |Stremio'
        self.movies['crime short 1989 - 1970 argentina'] = 'Ultimos dias de la victima (1982) Adolfo Aristarain |Stremio'
        self.movies['crime medium 2022 - 2008 international'] = 'The Mule (2018) Clint Eastwood |Stremio'
        self.movies['crime medium 2008 - 1998 international'] = 'Catch me if you can (2002) Steven Spielberg |Stremio'
        self.movies['crime medium 1998 - 1990 international'] = 'Leon: The Professional (1994) Leon Besson |Netflix'
        self.movies['crime medium 1989 - 1970 international'] = 'Blow Out (1981) Brian de Palma |Stremio'
        self.movies['crime medium 2022 - 2008 argentina'] = 'Muerte en Buenos Aires (2014) Natalia Meta |STAR+'
        self.movies['crime medium 2008 - 1998 argentina'] = 'Tiempo de valientes (2005) Damian Szifron |Stremio'
        self.movies['crime medium 1998 - 1990 argentina'] = 'El caso de Maria Soledad (1993) Hector Olivera |Stremio'
        self.movies['crime medium 1989 - 1970 argentina'] = 'Ultimos dias de la victima (1982) Adolfo Aristarain |Stremio'   
        self.movies['crime long 2022 - 2008 international'] = 'The Irishman (2019) Martin Scorsese |Netflix'
        self.movies['crime long 2008 - 1998 international'] = 'The departed (2006) Martin Scorsese |Stremio'
        self.movies['crime long 1998 - 1990 international'] = 'Pulp Fiction (1994) Quentin Tarantino |Netflix'
        self.movies['crime long 1989 - 1970 international'] = 'The Godfather (1972) Francis Ford Coppola |Netflix'
        self.movies['crime long 2022 - 2008 argentina'] = 'Muerte en Buenos Aires (2014) Natalia Meta |STAR+'
        self.movies['crime long 2008 - 1998 argentina'] = 'Tiempo de valientes (2005) Damian Szifron |Stremio'
        self.movies['crime long 1998 - 1990 argentina'] = 'El caso de Maria Soledad (1993) Hector Olivera |Stremio'
        self.movies['crime long 1989 - 1970 argentina'] = 'Ultimos dias de la victima (1982) Adolfo Aristarain |Stremio'
        self.movies['horror short 2022 - 2008 international'] = 'The Boy (2016) William Brent Eln |Netflix'
        self.movies['horror short 2008 - 1998 international'] = 'House of 1000 Corpses (2003) Rob Zombie |Stremio'
        self.movies['horror short 1998 - 1990 international'] = 'The Blair Witch Project (1998) Daniel Myrick |Stremio'
        self.movies['horror short 1989 - 1970 international'] = 'A Nightmare on Elm Street (1984) Wes Craven |Stremio'
        self.movies['horror short 2022 - 2008 argentina'] = 'Juan de los Muertos (2011) Alejandro Brugués |Stremio'
        self.movies['horror short 2008 - 1998 argentina'] = 'El Niño de Barro (2007) Jorge Algora |Stremio'
        self.movies['horror short 1998 - 1990 argentina'] = 'El Niño de Barro (2007) Jorge Algora |Stremio'
        self.movies['horror short 1989 - 1970 argentina'] = 'El Niño de Barro (2007) Jorge Algora |Stremio'
        self.movies['horror medium 2022 - 2008 international'] = 'Split (2016)  M. Night Shyamalan |Netflix'
        self.movies['horror medium 2008 - 1998 international'] = 'Saw (2004) James Wan |HBO MAX / Stremio'
        self.movies['horror medium 1998 - 1990 international'] = 'Scream (1996) Wes Craven |Stremio'
        self.movies['horror medium 1989 - 1970 international'] = 'The thing (1982) John Carpenter |Stremio'
        self.movies['horror medium 2022 - 2008 argentina'] = 'Juan de los Muertos (2011) Alejandro Brugués |Stremio'
        self.movies['horror medium 2008 - 1998 argentina'] = 'El Niño de Barro (2007) Jorge Algora |Stremio'
        self.movies['horror medium 1998 - 1990 argentina'] = 'El Niño de Barro (2007) Jorge Algora |Stremio'
        self.movies['horror medium 1989 - 1970 argentina'] = 'El Niño de Barro (2007) Jorge Algora |Stremio'   
        self.movies['horror long 2022 - 2008 international'] = 'The House That Jack Built (2018) Lars von Trier |Stremio'
        self.movies['horror long 2008 - 1998 international'] = 'Orphan (2008) Jaume Collet-Serra |Stremio'
        self.movies['horror long 1998 - 1990 international'] = 'Thesis (1996) Alejandro Amenabar |Amazon Prime'
        self.movies['horror long 1989 - 1970 international'] = 'The Shinning (1980) Stanley Kubrick |HBO MAX / Stremio'
        self.movies['horror long 2022 - 2008 argentina'] = 'Juan de los Muertos (2011) Alejandro Brugués |Stremio'
        self.movies['horror long 2008 - 1998 argentina'] = 'El Niño de Barro (2007) Jorge Algora |Stremio'
        self.movies['horror long 1998 - 1990 argentina'] = 'El Niño de Barro (2007) Jorge Algora |Stremio'
        self.movies['horror long 1989 - 1970 argentina'] = 'El Niño de Barro (2007) Jorge Algora |Stremio'  
        self.movies['science fiction short 2022 - 2008 international'] = 'Coherence (2013) James Ward Byrkit |Stremio'
        self.movies['science fiction short 2008 - 1998 international'] = 'The Butterfly Effect (2004) Eric Bress |Netflix'
        self.movies['science fiction short 1998 - 1990 international'] = 'The Iron Giant (1998) Brad Bird |Stremio'
        self.movies['science fiction short 1989 - 1970 international'] = 'The Fly (1984) David Cronenberg |STAR+'
        self.movies['science fiction short 2022 - 2008 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'
        self.movies['science fiction short 2008 - 1998 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'
        self.movies['science fiction short 1998 - 1990 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'
        self.movies['science fiction short 1989 - 1970 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'
        self.movies['science fiction medium 2022 - 2008 international'] = 'Ready Player One (2018) Steven Spielberg |HBO MAX / Stremio'
        self.movies['science fiction medium 2008 - 1998 international'] = 'Eternal Sunshine of the Spotless Mind (2004) Michael Gondry |Netflix'
        self.movies['science fiction medium 1998 - 1990 international'] = 'The Matrix (1998) Lilly Wachowski |Stremio'
        self.movies['science fiction medium 1989 - 1970 international'] = 'The Swarm (1978) Irwin Allen |Stremio'
        self.movies['science fiction medium 2022 - 2008 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'
        self.movies['science fiction medium 2008 - 1998 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'
        self.movies['science fiction medium 1998 - 1990 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'
        self.movies['science fiction medium 1989 - 1970 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'   
        self.movies['science fiction long 2022 - 2008 international'] = 'Interstellar (2014) Christopher Nolan |Stremio'
        self.movies['science fiction long 2008 - 1998 international'] = 'Avatar (2008) James Cameron |Disney+'
        self.movies['science fiction long 1998 - 1990 international'] = 'Terminator 2: Judgment Day (1996) James Cameron |Disney+'
        self.movies['science fiction long 1989 - 1970 international'] = 'E.T. the Extra-Terrestrial (1982) Steven Spielberg |Stremio'
        self.movies['science fiction long 2022 - 2008 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'
        self.movies['science fiction long 2008 - 1998 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'
        self.movies['science fiction long 1998 - 1990 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'
        self.movies['science fiction long 1989 - 1970 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'    
#-----------------------------INPUT DE DATOS----------------------------#
    @Rule(AS.f1 << hasGenre == True)
    def inputGenre(self, f1):
        retract(f1)
        question = ", ".join(
            "({key}) {name}".format(
                key=a[0].upper(), name=a[1].title())
            for a in self.valid_answers_genre.items())
        print('\t 1) Select the genre of the movie')
        print(question)
        res = input().lower()
        if res in self.valid_answers_genre:
            self.genre = self.valid_answers_genre.get(res)
        else:
            print("Sorry %s is not a valid genre \n" % res)
            self.inputGenre()
    
    def inputDuration(self):
        question = ", ".join(
            "({key}) {name}".format(
                key=a[0].upper(), name=a[1].title())
            for a in self.valid_answers_duration.items())
        print('\n \t 2) Select the duration of the movie')
        print(question)
        res = input().lower()
        if res in self.valid_answers_duration:
            self.duration = res
        else:
            print("Sorry %s is not a valid duration \n" % res)
            self.inputDuration()
            
    def inputYear(self):
        question = ", ".join(
            "({key}) {name}".format(
                key=a[0].upper(), name=a[1].title())
            for a in self.valid_answers_year.items())
        print('\n \t 3) Select the year of the movie')
        print(question)
        res = input().lower()
        if res in self.valid_answers_year:
            self.year = self.valid_answers_year.get(res)
        else:
            print("Sorry %s is not a valid year" % res)
            self.inputYear()
            
    def inputCountry(self):
        question = ", ".join(
            "({key}) {name}".format(
                key=a[0].upper(), name=a[1].title())
            for a in self.valid_answers_country.items())
        print('\n \t 4) Select the country of the movie')
        print(question)
        res = input().lower()
        if res in self.valid_answers_country:
            self.country = self.valid_answers_country.get(res)
        else:
            print("Sorry %s is not a valid country" % res)
            self.inputCountry()
#----------------------------OBTENCION DE RESULTADOS----------------------------#            
    def get_movie(self):
        tags = self.genre + ' ' + self.duration + ' ' + self.year + ' ' + self.country
        print('---------------------------------------------------')
        movie_name = ''
        for i in range(len(self.movies.get(tags))):
            if self.movies.get(tags)[i] != '|':
                movie_name += self.movies.get(tags)[i]
            else:
                break
                
        where_to_watch = ''
        put_letter = False
        for i in range(len(self.movies.get(tags))):
            if put_letter == True:
                where_to_watch += self.movies.get(tags)[i]
            if self.movies.get(tags)[i] == '|':
                put_letter = True
                
        print('The movie that best suits your preferences is:', movie_name)
        print('You can watch it in', where_to_watch)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-5ffbc58ddf4d> in <module>
#       3     pass
#       4
# ----> 5 class MovieSelector(KnowledgeEngine):
#       6     valid_answers_genre = dict()
#       7     valid_answers_duration = dict()
#
# <ipython-input-7-5ffbc58ddf4d> in MovieSelector()
#     146         self.movies['science fiction long 1989 - 1970 argentina'] = 'Fase 7 (2010) Nicolás Goldbart |Stremio'
#     147 #-----------------------------INPUT DE DATOS----------------------------#
# --> 148     @Rule(AS.f1 << hasGenre == True)
#     149     def inputGenre(self, f1):
#     150         retract(f1)
#
# TypeError: unsupported operand type(s) for <<: 'str' and 'bool'

# %%
engine = MovieSelector()
engine.reset()
engine.run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2689d9b882c1> in <module>
# ----> 1 engine = MovieSelector()
#       2 engine.reset()
#       3 engine.run()
#
# /usr/local/lib/python3.8/dist-packages/pyknow-1.7.0-py3.8.egg/pyknow/engine.py in __init__(self)
#      40         if (isinstance(self.__matcher__, type)
#      41                 and issubclass(self.__matcher__, abstract.Matcher)):
# ---> 42             self.matcher = self.__matcher__(self)
#      43         else:
#      44             raise TypeError("__matcher__ must be a subclass of Matcher")
#
# /usr/local/lib/python3.8/dist-packages/pyknow-1.7.0-py3.8.egg/pyknow/matchers/rete/__init__.py in __init__(self, *args, **kwargs)
#      29         super().__init__(*args, **kwargs)
#      30         self.root_node = BusNode()
# ---> 31         self.build_network()
#      32
# ...
